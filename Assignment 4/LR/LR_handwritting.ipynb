# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import softmax
from sklearn.metrics import confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
import statistics
import seaborn as sns
from modules.stats import *
from modules.PCA import *
from modules.LDA import *
from modules.read_data import *
from modules.LR import *
from modules.KNN import *
from modules.DTW import *
from modules.ROC import *

# %%
#LR
path = 'Assets/Handwriting Dataset'
# Given Datasets
data_class = ['a', 'bA', 'dA', 'lA', 'tA']

B = []
C = [] #train
D = [] #dev
# Read Data
for i in data_class:
	C.append(read_handwritting(path, i, 'train')[1])
	D.append(read_handwritting(path, i, 'dev')[1])
	B.append(read_handwritting(path, i, 'dev')[0])
C_y = []
D_y = []

for i in range(5):
	C_y.append(i * np.ones(len(C[i])))
	D_y.append(i * np.ones(len(D[i])))
X =  np.concatenate(C, axis=0)
X_d = np.concatenate(D, axis=0)
Y = np.concatenate(C_y, axis=0)
Y_d = np.concatenate(D_y, axis=0)
pca = True
lda = False
lda = ~pca & lda #if pca is true then lda is false
if pca:
	pc = 1
	μ, Σ = stats(X)
	eigval, Q = PCA(Σ, pc)
	X = X @ Q
	X_d = X_d @ Q
if lda:
	pc = 1
	μ, Σ = stats(X)
	μk = []
	for c in range(5):
		μk.append(stats(X[Y == c])[0])
	μk = np.array(μk)
	v = LDA(X,Y,μ,μk,pc)
	X = np.abs(X @ v)
	X_d = np.abs(X_d @ v)
if pca or lda:	
	C_new = []
	D_new = []
	nc=0
	nd=0
	for i in range(5):
		c = X[nc:nc+C[i].shape[0]]
		d = X_d[nd:nd+D[i].shape[0]]
		C_new.append(c)
		D_new.append(d)
		nc += C[i].shape[0]
		nd += D[i].shape[0]
	D = D_new
	C = C_new
train_data = C; total_train = X 
dev_data = D; total_dev = X_d
#training LR
loss_steps, w_ml = gradient_descent(train_data)

#error vs iter 
plt.plot(loss_steps['step'], loss_steps['error'])
plt.xlabel('step'); plt.ylabel('error')

#making prediction
p = softmax(- total_dev @ w_ml, axis=1)
t = np.argmax(p, axis=1)

P = []
for c in range(5):
	s = dev_data[c].shape[0]
	P.append(t[:s])
	t = np.delete(t, slice(s), 0)
# print(P[0])
y_pred = np.vstack((P[0].reshape(-1,1), P[1].reshape(-1,1), P[2].reshape(-1,1), P[3].reshape(-1,1), P[4].reshape(-1,1))).flatten()
Yn_d = []
for c in range(5):
	Yn_d.append(c * np.ones(len(B[c])))
Yn_d = np.array(Yn_d)

yn_pred = np.zeros_like(Yn_d)
n = 0
for c in range(5):
	for i in range(len(B[c])):
		data = y_pred[n:n+B[c][i].shape[0]]
		n += B[c][i].shape[0]
		yn_pred[c][i] = statistics.mode(data)
cm = confusion_matrix( yn_pred.flatten(), Yn_d.flatten(),)
accuracy = accuracy_score(Yn_d.flatten(),yn_pred.flatten())
ax = sns.heatmap(cm, annot = True, cmap ='plasma',linecolor ='black', linewidths = 1, fmt = '.0f', xticklabels = data_class, yticklabels = data_class)
ax.set_title(f'Accuracy = {accuracy}')
TPR2 = 0; FPR2 = 0
for c in range(5):
	tpr, fpr = ROC(label_binarize(Y_d, classes=[0,1,2,3,4])[:,c], p[:,c])
	TPR2 += tpr/5
	FPR2 += fpr/5

# %%
# %store TPR2
# %store FPR2
# Out:
# Stored 'TPR2' (ndarray)
# Stored 'FPR2' (ndarray)

# %%
#KNN
path = 'Assets/Handwriting Dataset'
# Given Datasets
data_class = ['a', 'bA', 'dA', 'lA', 'tA']

C = [] #train
D = [] #dev
# Read Data
for i in data_class:
	C.append(read_handwritting(path, i, 'train')[0])
	D.append(read_handwritting(path, i, 'dev')[0])
C_y = []
D_y = []

for i in range(5):
	C_y.append(i * np.ones(len(C[i])))
	D_y.append(i * np.ones(len(D[i])))
Cn = []
Dn = []
for c in range(5):
	C_new = np.array(C[c][0])
	D_new = np.array(D[c][0])
	for i in range(1,len(C[c])):
		C_new = np.vstack((C_new, np.array(C[c][i])))
	for i in range(1,len(D[c])):
		D_new = np.vstack((D_new, np.array(D[c][i])))
	Cn.append(C_new)
	Dn.append(D_new)
Yn = []
Yn_d = []

for i in range(5):
	Yn.append(i * np.ones(len(Cn[i])))
	Yn_d.append(i * np.ones(len(Dn[i])))

Yn = np.concatenate(Yn, axis=0)
Yn_d = np.concatenate(Yn_d, axis=0)
X = np.concatenate(Cn, axis=0)
X_d = np.concatenate(Dn, axis=0)
Y = np.concatenate(C_y, axis=0)
Y_d = np.concatenate(D_y, axis=0)
# pca = False
# lda = False
# lda = ~pca & lda #if pca is true then lda is false
# if pca:
# 	pc = 1
# 	μ, Σ = stats(X)
# 	eigval, Q = PCA(Σ, pc)
# 	X = X @ Q
# 	X_d = X_d @ Q
# if lda:
# 	pc = 1
# 	μ, Σ = stats(X)
# 	μk = []
# 	for c in range(5):
# 		μk.append(stats(X[Yn == c])[0])
# 	μk = np.array(μk)
# 	v = LDA(X,Yn,μ,μk,pc)
# 	X = np.abs(X @ v)
# 	X_d = np.abs(X_d @ v)
# if pca or lda:
# 	cn = 0
# 	dn = 0
# 	C_new = []
# 	D_new = []
# 	for c in range(5):
# 		t = []
# 		d = []
# 		for i in range(len(C[c])):
# 			t.append(X[cn:cn+len(C[c][i])])
# 			cn += len(C[c][i])
# 		for i in range(len(D[c])):
# 			d.append(X_d[dn:dn+len(D[c][i])])
# 			dn += len(D[c][i])
# 		D_new.append(d)
# 		C_new.append(t)
# 	D = D_new
# 	C = C_new
# P = []
# for cl in range(5):
# 	p = []
# 	for dev in D[cl]:
# 		cost = []
# 		for c in range(5):
# 			for train in C[c]:
# 				cost.append([DTW(dev, train)[-1,-1], c])
# 		cost = np.array(cost)
# 		idx = cost[:,0].argsort()
# 		cost = cost[idx]
# 		p.append(cost[:, 1])
# 	P.append(p)
# k = 10
# Q = []
# score = []
# for c in range(5):
# 	q = []
# 	s = []
# 	for j in range(len(D[c])):
# 		data = P[c][j][:k]
# 		q.append(statistics.mode(data))
# 		s.append(np.array([(data==0).sum()/k, (data==1).sum()/k, (data==2).sum()/k, (data==3).sum()/k, (data==4).sum()/k]))
# 	Q.append(q)
# 	score.append(s)
# y_pred = np.concatenate(Q)
# score = np.concatenate(score)
# cm = confusion_matrix(Y_d, y_pred)
# accuracy = accuracy_score(Y_d,y_pred)
# ax = sns.heatmap(cm, annot = True, cmap ='plasma',linecolor ='black', linewidths = 1, fmt = '.0f', xticklabels = data_class, yticklabels = data_class)
# ax.set_title(f'Accuracy = {accuracy}')
# TPR2 = 0; FPR2 = 0
# for c in range(5):
# 	tpr, fpr = ROC(label_binarize(Y_d, classes=[0,1,2,3,4])[:,c], score[:,c])
# 	TPR2 += tpr/5
# 	FPR2 += fpr/5

# %%
y_pred = np.concatenate(Q)
# score = np.concatenate(score)
cm = confusion_matrix(y_pred, Y_d)
accuracy = accuracy_score(y_pred, Y_d)
ax = sns.heatmap(cm, annot = True, cmap ='plasma',linecolor ='black', linewidths = 1, fmt = '.0f', xticklabels = data_class, yticklabels = data_class)
ax.set_title(f'Accuracy = {accuracy}')
# Out:
# Text(0.5, 1.0, 'Accuracy = 1.0')

# %%
#SVM
from sklearn import svm
path = 'Assets/Handwriting Dataset'
# Given Datasets
data_class = ['a', 'bA', 'dA', 'lA', 'tA']

B = []
C = [] #train
D = [] #dev
# Read Data
for i in data_class:
	C.append(read_handwritting(path, i, 'train')[0])
	D.append(read_handwritting(path, i, 'dev')[0])
	B.append(read_handwritting(path, i, 'dev')[0])
Cn = []
Dn = []
for c in range(5):
	C_new = np.array(C[c][0])
	D_new = np.array(D[c][0])
	for i in range(1,len(C[c])):
		C_new = np.vstack((C_new, np.array(C[c][i])))
	for i in range(1,len(D[c])):
		D_new = np.vstack((D_new, np.array(D[c][i])))
	Cn.append(C_new)
	Dn.append(D_new)
C = Cn
D = Dn
C_y = []
D_y = []

for i in range(5):
	C_y.append(i * np.ones(C[i].shape[0]))
	D_y.append(i * np.ones(D[i].shape[0]))
X = np.concatenate(C, axis=0)
X_d = np.concatenate(D, axis=0)
Y = np.concatenate(C_y, axis=0)
Y_d = np.concatenate(D_y, axis=0)
pca = False
lda = False
lda = ~pca & lda #if pca is true then lda is false
if pca:
	pc = 1
	μ, Σ = stats(X)
	eigval, Q = PCA(Σ, pc)
	X = X @ Q
	X_d = X_d @ Q
if lda:
	pc = 1
	μ, Σ = stats(X)
	μk = []
	for c in range(5):
		μk.append(stats(X[Y == c])[0])
	μk = np.array(μk)
	v = LDA(X,Y,μ,μk,pc)
	X = np.abs(X @ v)
	X_d = np.abs(X_d @ v)
clf = svm.SVC(probability=True)
clf.fit(X, Y)
y_pred = clf.predict(X_d)
score = clf.predict_proba(X_d)
Yn_d = []
for c in range(5):
	Yn_d.append(c * np.ones(len(B[c])))
Yn_d = np.array(Yn_d)

yn_pred = np.zeros_like(Yn_d)
n = 0
for c in range(5):
	for i in range(len(B[c])):
		data = y_pred[n:n+B[c][i].shape[0]]
		n += B[c][i].shape[0]
		yn_pred[c][i] = statistics.mode(data)
cm = confusion_matrix(yn_pred.flatten(), Yn_d.flatten())
accuracy = accuracy_score(Yn_d.flatten(),yn_pred.flatten())
ax = sns.heatmap(cm, annot = True, cmap ='plasma',linecolor ='black', linewidths = 1, fmt = '.0f', xticklabels = data_class, yticklabels = data_class)
ax.set_title(f'Accuracy = {accuracy}')
TPR3 = 0; FPR3 = 0
for c in range(5):
	tpr, fpr = ROC(label_binarize(Y_d, classes=[0,1,2,3,4])[:,c], score[:,c])
	TPR3 += tpr/5
	FPR3 += fpr/5

# %%
#ANN
from keras.models import Sequential
from keras.layers import Dense
path = 'Assets/Handwriting Dataset'
# Given Datasets
data_class = ['a', 'bA', 'dA', 'lA', 'tA']

B = []
C = [] #train
D = [] #dev
# Read Data
for i in data_class:
	C.append(read_handwritting(path, i, 'train')[1])
	D.append(read_handwritting(path, i, 'dev')[1])
	B.append(read_handwritting(path, i, 'dev')[0])
C_y = []
D_y = []

for i in range(5):
	C_y.append(i * np.ones(C[i].shape[0]))
	D_y.append(i * np.ones(D[i].shape[0]))
X = np.concatenate(C, axis=0)
X_d = np.concatenate(D, axis=0)
Y = np.concatenate(C_y, axis=0)
Y_d = np.concatenate(D_y, axis=0)
pca = False
lda = False
lda = ~pca & lda #if pca is true then lda is false
if pca:
	pc = 1
	μ, Σ = stats(X)
	eigval, Q = PCA(Σ, pc)
	X = X @ Q
	X_d = X_d @ Q
if lda:
	pc = 1
	μ, Σ = stats(X)
	μk = []
	for c in range(5):
		μk.append(stats(X[Y == c])[0])
	μk = np.array(μk)
	v = LDA(X,Y,μ,μk,pc)
	X = np.abs(X @ v)
	X_d = np.abs(X_d @ v)
classifier = Sequential()
classifier.add(Dense(512, input_shape=(X.shape[1],), kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dense(512, input_shape=(X.shape[1],), kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dense(5, kernel_initializer = 'uniform', activation = 'softmax'))
classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
classifier.fit(X, label_binarize(Y, classes=[0,1,2,3,4]), batch_size = 50, epochs = 100)
score = classifier.predict(X_d)
y_pred = np.argmax(score,axis=1)
Yn_d = []
for c in range(5):
	Yn_d.append(c * np.ones(len(B[c])))
Yn_d = np.array(Yn_d)

yn_pred = np.zeros_like(Yn_d)
n = 0
for c in range(5):
	for i in range(len(B[c])):
		data = y_pred[n:n+B[c][i].shape[0]]
		n += B[c][i].shape[0]
		yn_pred[c][i] = statistics.mode(data)
cm = confusion_matrix(yn_pred.flatten(), Yn_d.flatten())
accuracy = accuracy_score(Yn_d.flatten(),yn_pred.flatten())
ax = sns.heatmap(cm, annot = True, cmap ='plasma',linecolor ='black', linewidths = 1, fmt = '.0f', xticklabels = data_class, yticklabels = data_class)
ax.set_title(f'Accuracy = {accuracy}')
TPR4 = 0; FPR4 = 0
for c in range(5):
	tpr, fpr = ROC(label_binarize(Y_d, classes=[0,1,2,3,4])[:,c], score[:,c])
	TPR4 += tpr/5
	FPR4 += fpr/5
# Out:
# Epoch 1/100
# 2022-05-03 20:38:04.772910: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 513/513 [==============================] - 1s 2ms/step - loss: 1.5745 - accuracy: 0.2730
# Epoch 2/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.5478 - accuracy: 0.2870
# Epoch 3/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.5326 - accuracy: 0.2946
# Epoch 4/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.5223 - accuracy: 0.3055
# Epoch 5/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.5164 - accuracy: 0.3080
# Epoch 6/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.5091 - accuracy: 0.3137
# Epoch 7/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.5012 - accuracy: 0.3235
# Epoch 8/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4942 - accuracy: 0.3272
# Epoch 9/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4855 - accuracy: 0.3364
# Epoch 10/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4796 - accuracy: 0.3351
# Epoch 11/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4726 - accuracy: 0.3376
# Epoch 12/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4679 - accuracy: 0.3418
# Epoch 13/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4614 - accuracy: 0.3460
# Epoch 14/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4561 - accuracy: 0.3477
# Epoch 15/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4511 - accuracy: 0.3481
# Epoch 16/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4492 - accuracy: 0.3512
# Epoch 17/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4450 - accuracy: 0.3522
# Epoch 18/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4426 - accuracy: 0.3536
# Epoch 19/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4414 - accuracy: 0.3531
# Epoch 20/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4373 - accuracy: 0.3536
# Epoch 21/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4333 - accuracy: 0.3571
# Epoch 22/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4346 - accuracy: 0.3549
# Epoch 23/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4322 - accuracy: 0.3557
# Epoch 24/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4310 - accuracy: 0.3556
# Epoch 25/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4291 - accuracy: 0.3581
# Epoch 26/100
# 513/513 [==============================] - 1s 3ms/step - loss: 1.4278 - accuracy: 0.3606
# Epoch 27/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4274 - accuracy: 0.3580
# Epoch 28/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4257 - accuracy: 0.3570
# Epoch 29/100
# 513/513 [==============================] - 2s 4ms/step - loss: 1.4236 - accuracy: 0.3615
# Epoch 30/100
# 513/513 [==============================] - 3s 5ms/step - loss: 1.4240 - accuracy: 0.3622
# Epoch 31/100
# 513/513 [==============================] - 2s 4ms/step - loss: 1.4227 - accuracy: 0.3604
# Epoch 32/100
# 513/513 [==============================] - 2s 4ms/step - loss: 1.4220 - accuracy: 0.3618
# Epoch 33/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4217 - accuracy: 0.3621
# Epoch 34/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4224 - accuracy: 0.3575
# Epoch 35/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4199 - accuracy: 0.3622
# Epoch 36/100
# 513/513 [==============================] - 2s 4ms/step - loss: 1.4208 - accuracy: 0.3599
# Epoch 37/100
# 513/513 [==============================] - 2s 4ms/step - loss: 1.4180 - accuracy: 0.3630
# Epoch 38/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4185 - accuracy: 0.3624
# Epoch 39/100
# 513/513 [==============================] - 2s 4ms/step - loss: 1.4197 - accuracy: 0.3638
# Epoch 40/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4182 - accuracy: 0.3599
# Epoch 41/100
# 513/513 [==============================] - 1s 3ms/step - loss: 1.4186 - accuracy: 0.3635
# Epoch 42/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4182 - accuracy: 0.3625
# Epoch 43/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4175 - accuracy: 0.3576
# Epoch 44/100
# 513/513 [==============================] - 2s 4ms/step - loss: 1.4167 - accuracy: 0.3650
# Epoch 45/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4156 - accuracy: 0.3639
# Epoch 46/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4163 - accuracy: 0.3619
# Epoch 47/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4159 - accuracy: 0.3654
# Epoch 48/100
# 513/513 [==============================] - 1s 3ms/step - loss: 1.4154 - accuracy: 0.3624
# Epoch 49/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4148 - accuracy: 0.3645
# Epoch 50/100
# 513/513 [==============================] - 1s 3ms/step - loss: 1.4132 - accuracy: 0.3662
# Epoch 51/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4144 - accuracy: 0.3614
# Epoch 52/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4125 - accuracy: 0.3643
# Epoch 53/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4137 - accuracy: 0.3638
# Epoch 54/100
# 513/513 [==============================] - 1s 3ms/step - loss: 1.4137 - accuracy: 0.3656
# Epoch 55/100
# 513/513 [==============================] - 1s 3ms/step - loss: 1.4138 - accuracy: 0.3626
# Epoch 56/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4126 - accuracy: 0.3644
# Epoch 57/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4133 - accuracy: 0.3621
# Epoch 58/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4114 - accuracy: 0.3658
# Epoch 59/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4117 - accuracy: 0.3679
# Epoch 60/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4117 - accuracy: 0.3651
# Epoch 61/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4116 - accuracy: 0.3672
# Epoch 62/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4111 - accuracy: 0.3666
# Epoch 63/100
# 513/513 [==============================] - 1s 3ms/step - loss: 1.4102 - accuracy: 0.3667
# Epoch 64/100
# 513/513 [==============================] - 1s 3ms/step - loss: 1.4109 - accuracy: 0.3649
# Epoch 65/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4104 - accuracy: 0.3672
# Epoch 66/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4102 - accuracy: 0.3682
# Epoch 67/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4098 - accuracy: 0.3639
# Epoch 68/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4100 - accuracy: 0.3633
# Epoch 69/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4097 - accuracy: 0.3652
# Epoch 70/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4096 - accuracy: 0.3665
# Epoch 71/100
# 513/513 [==============================] - 1s 3ms/step - loss: 1.4088 - accuracy: 0.3681
# Epoch 72/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4090 - accuracy: 0.3682
# Epoch 73/100
# 513/513 [==============================] - 1s 3ms/step - loss: 1.4099 - accuracy: 0.3656
# Epoch 74/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4081 - accuracy: 0.3686
# Epoch 75/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4084 - accuracy: 0.3657
# Epoch 76/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4071 - accuracy: 0.3681
# Epoch 77/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4087 - accuracy: 0.3661
# Epoch 78/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4083 - accuracy: 0.3670
# Epoch 79/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4061 - accuracy: 0.3679
# Epoch 80/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4075 - accuracy: 0.3691
# Epoch 81/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4073 - accuracy: 0.3678
# Epoch 82/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4075 - accuracy: 0.3685
# Epoch 83/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4066 - accuracy: 0.3686
# Epoch 84/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4072 - accuracy: 0.3651
# Epoch 85/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4068 - accuracy: 0.3710
# Epoch 86/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4079 - accuracy: 0.3662
# Epoch 87/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4063 - accuracy: 0.3698
# Epoch 88/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4060 - accuracy: 0.3677
# Epoch 89/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4060 - accuracy: 0.3670
# Epoch 90/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4066 - accuracy: 0.3678
# Epoch 91/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4057 - accuracy: 0.3674
# Epoch 92/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4064 - accuracy: 0.3670
# Epoch 93/100
# 513/513 [==============================] - 1s 2ms/step - loss: 1.4045 - accuracy: 0.3671
# Epoch 94/100
# 513/513 [==============================] - 1s 3ms/step - loss: 1.4059 - accuracy: 0.3684
# Epoch 95/100
# 513/513 [==============================] - 1s 3ms/step - loss: 1.4054 - accuracy: 0.3690
# Epoch 96/100
# 513/513 [==============================] - 1s 3ms/step - loss: 1.4049 - accuracy: 0.3708
# Epoch 97/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4041 - accuracy: 0.3671
# Epoch 98/100
# 513/513 [==============================] - 2s 3ms/step - loss: 1.4057 - accuracy: 0.3677
# Epoch 99/100
# 513/513 [==============================] - 1s 3ms/step - loss: 1.4044 - accuracy: 0.3707
# Epoch 100/100
# 513/513 [==============================] - 1s 3ms/step - loss: 1.4047 - accuracy: 0.3713

# %%
plt.plot(FPR1, TPR1, 'b')
plt.plot(FPR2, TPR2, 'r')
plt.plot(FPR3, TPR3, 'g')
plt.plot(FPR4, TPR4)
plt.xlabel('False Positive Rate',fontsize=12); plt.ylabel('True Positive Rate',fontsize=12)
plt.title('ROC All Classifiers',fontweight="bold", fontsize=14)
plt.legend(['LR', 'KNN', 'SVM', 'ANN'])

# %%
plt.plot(FPR1, TPR1, 'b')

# %%
# %store TPR1
# %store FPR1
# Out:
# Stored 'TPR1' (ndarray)
# Stored 'FPR1' (ndarray)
